# %%
import numpy as np
import pandas as pd
from transformTest import Transform
from Model2 import Model2
from collections import Counter
from sklearn.metrics import f1_score,confusion_matrix,accuracy_score
import matplotlib.pyplot as plt

# %%
test_data = Transform.create_test_data(224,"C:/Users/Vandana/Desktop/cmpe 257/CMPE_257_final/data/test")
X = Transform.createArray(test_data,224)

# %%
print(len(X))
import warnings
warnings.filterwarnings('ignore')
# Out:
# 31

# %%
model = Model2()
labels=["pothole","no pothole"]
for i in X:
    #Predict using Logistic Regression trained model
    model.load_model("models/model2_rf")
    test = np.array([i])
    plt.imshow(i)
    plt.show()
    y_pred = model.predict(test)
    print("Random Forest: %s"%(labels[y_pred[0]]))
    model.load_model("models/model2_lr")
    y_pred = model.predict(test)
    print("Logistic Regression: %s"%(labels[y_pred[0]]))
    model.load_model("models/model2_svm")
    y_pred = model.predict(test)
    print("SVM: %s"%(labels[y_pred[0]]))
# Out:
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: no pothole
# Logistic Regression: no pothole
# SVM: no pothole
# Random Forest: pothole
# Logistic Regression: no pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: no pothole
# SVM: no pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# SVM: pothole
# Random Forest: pothole
# Logistic Regression: pothole
# ...
